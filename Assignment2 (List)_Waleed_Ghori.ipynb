# %%
#Write a program that prints the length of the list.
_food = ["Biryani","White Karhai", "Bihari Tikka", "Malai Boti", "Katakat","Nihari", "Pulao"]
print("Food:",_food)

print("Length of Food List:", len(_food))
# Out:
# Food: ['Biryani', 'White Karhai', 'Bihari Tikka', 'Malai Boti', 'Katakat', 'Nihari', 'Pulao']
# Length of Food List: 7

# %%
#Write a Python program to sum all the numeric items in a list?

num_list = [1,2,5,6,9,7,8]
print("Numeric List:",num_list)

print("Sum of Numeric List:", sum(num_list))
# Out:
# Numeric List: [1, 2, 5, 6, 9, 7, 8]
# Sum of Numeric List: 38

# %%
# Write a Python Program to get the largest number from a numeric list?

number_list = [1,3,5,9,18,20]
print("List:", number_list)

print("Maximum Number in List" , max(number_list))
# Out:
# List: [1, 3, 5, 9, 18, 20]
# Maximum Number in List 20
